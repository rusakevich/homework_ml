# %%
import pandas as pd
import numpy as np
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from pymystem3 import Mystem
import pickle

# %%
# Чтение данных
with open('duma/data_dataframe.pickle', 'rb') as dep:
    data = pickle.load(dep)

# %%
# Функция для удаления фио из стенограмм
def fio(x):
    a = x['name'].lower().split()
    f = a[0]
    i = a[1][0]
    o = a[2][0]
    a = '{} {} {} '.format(f, i, o)
    return re.sub(a, "", x['_lines'])

# %%
data['_lines'] = data['_lines'].apply(lambda x: re.sub(r'\s+', ' ', ' '.join(x)))
data['_lines'] = data['_lines'].apply(lambda x: re.sub(r'[^\w\s]', '', x.lower()))
data['_lines'] = data['_lines'].apply(lambda x: x.strip())
data['_lines'] = data.apply(fio, axis=1)

# %%
data
# Out:
#         _startLine  _endLine     _type  \
# 0             1043      1051
# 1             1203      1212  65100003
# 2             4581      4593  65100003
# 3             1819      1830  65100003
# 4             2591      2617  65100003
# ...            ...       ...       ...
# 359325        3535      3536
# 359326         882       885
# 359327         450       466
# 359328         667       673
# 359329        3113      3118
#
#                                                    _lines _votes  \
# 0       фракция единая россия спасибо уважаемый борис ...     []
# 1       спасибо уважаемый борис вячеславович уважаемые...     []
# 2       уважаемый председательствующий уважаемые колле...     []
# 3       фракция единая россия уважаемый председательст...     []
# 4       фракция единая россия уважаемый председательст...     []
# ...                                                   ...    ...
# 359325                                                нет     []
# 359326  фракция коммунистической партии российской фед...     []
# 359327  куваев аа фракция коммунистической партии росс...     []
# 359328  куваев аа фракция коммунистической партии росс...     []
# 359329  куваев аа избирательное объединение коммунисти...     []
#
#                                   name pageSize page totalCount questionCount  \
# 0           Колесников Виктор Иванович       20    1        348           193
# 1           Колесников Виктор Иванович       20    1        348           193
# 2           Колесников Виктор Иванович       20    1        348           193
# 3           Колесников Виктор Иванович       20    1        348           193
# 4           Колесников Виктор Иванович       20    1        348           193
# ...                                ...      ...  ...        ...           ...
# 359325  Куваев Александр Александрович       20    2         25            20
# 359326  Куваев Александр Александрович       20    2         25            20
# 359327  Куваев Александр Александрович       20    2         25            20
# 359328  Куваев Александр Александрович       20    2         25            20
# 359329  Куваев Александр Александрович       20    2         25            20
#
#               meetings.date  deputies  \
# 0       2011-11-18 00:00:00  99102994
# 1       2011-11-18 00:00:00  99102994
# 2       2011-11-18 00:00:00  99102994
# 3       2011-10-21 00:00:00  99102994
# 4       2011-10-18 00:00:00  99102994
# ...                     ...       ...
# 359325  2000-09-20 00:00:00  99103327
# 359326  2000-07-07 00:00:00  99103327
# 359327  1998-09-09 00:00:00  99103327
# 359328  1997-09-03 00:00:00  99103327
# 359329  1996-01-16 00:00:00  99103327
#
#                                                     party
# 0                                                    None
# 1                                                    None
# 2                                                    None
# 3                                                    None
# 4                                                    None
# ...                                                   ...
# 359325  Фракция Политической партии "КОММУНИСТИЧЕСКАЯ ...
# 359326  Фракция Политической партии "КОММУНИСТИЧЕСКАЯ ...
# 359327  Фракция Политической партии "КОММУНИСТИЧЕСКАЯ ...
# 359328  Фракция Политической партии "КОММУНИСТИЧЕСКАЯ ...
# 359329  Фракция Политической партии "КОММУНИСТИЧЕСКАЯ ...
#
# [359330 rows x 13 columns]

# %%
# Создание объекта лематизатора, загрузка стоп-слов и русского словаря
lem = Mystem()
nltk.download('stopwords')
stop = stopwords.words('russian')
# Out:
# Installing mystem to /Users/V.Rusakevich/.local/bin/mystem from http://download.cdn.yandex.net/mystem/mystem-3.1-macosx.tar.gz
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/V.Rusakevich/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# Функция лематизации
def prep(x):
    return [word.rstrip() for word in (''.join(lem.lemmatize(x))).split(' ') if (word not in stop and word != '')]

# %%
# %%time
# Лематизация
data['lines'] = data['_lines'].apply(prep)
# Out:
# CPU times: user 4min 25s, sys: 12.3 s, total: 4min 37s
# Wall time: 41min 52s

# %%
data
# Out:
#         _startLine  _endLine     _type  \
# 0             1043      1051
# 1             1203      1212  65100003
# 2             4581      4593  65100003
# 3             1819      1830  65100003
# 4             2591      2617  65100003
# ...            ...       ...       ...
# 359325        3535      3536
# 359326         882       885
# 359327         450       466
# 359328         667       673
# 359329        3113      3118
#
#                                                    _lines _votes  \
# 0       фракция единая россия спасибо уважаемый борис ...     []
# 1       спасибо уважаемый борис вячеславович уважаемые...     []
# 2       уважаемый председательствующий уважаемые колле...     []
# 3       фракция единая россия уважаемый председательст...     []
# 4       фракция единая россия уважаемый председательст...     []
# ...                                                   ...    ...
# 359325                                                нет     []
# 359326  фракция коммунистической партии российской фед...     []
# 359327  куваев аа фракция коммунистической партии росс...     []
# 359328  куваев аа фракция коммунистической партии росс...     []
# 359329  куваев аа избирательное объединение коммунисти...     []
#
#                                   name pageSize page totalCount questionCount  \
# 0           Колесников Виктор Иванович       20    1        348           193
# 1           Колесников Виктор Иванович       20    1        348           193
# 2           Колесников Виктор Иванович       20    1        348           193
# 3           Колесников Виктор Иванович       20    1        348           193
# 4           Колесников Виктор Иванович       20    1        348           193
# ...                                ...      ...  ...        ...           ...
# 359325  Куваев Александр Александрович       20    2         25            20
# 359326  Куваев Александр Александрович       20    2         25            20
# 359327  Куваев Александр Александрович       20    2         25            20
# 359328  Куваев Александр Александрович       20    2         25            20
# 359329  Куваев Александр Александрович       20    2         25            20
#
#               meetings.date  deputies  \
# 0       2011-11-18 00:00:00  99102994
# 1       2011-11-18 00:00:00  99102994
# 2       2011-11-18 00:00:00  99102994
# 3       2011-10-21 00:00:00  99102994
# 4       2011-10-18 00:00:00  99102994
# ...                     ...       ...
# 359325  2000-09-20 00:00:00  99103327
# 359326  2000-07-07 00:00:00  99103327
# 359327  1998-09-09 00:00:00  99103327
# 359328  1997-09-03 00:00:00  99103327
# 359329  1996-01-16 00:00:00  99103327
#
#                                                     party  \
# 0                                                    None
# 1                                                    None
# 2                                                    None
# 3                                                    None
# 4                                                    None
# ...                                                   ...
# 359325  Фракция Политической партии "КОММУНИСТИЧЕСКАЯ ...
# 359326  Фракция Политической партии "КОММУНИСТИЧЕСКАЯ ...
# 359327  Фракция Политической партии "КОММУНИСТИЧЕСКАЯ ...
# 359328  Фракция Политической партии "КОММУНИСТИЧЕСКАЯ ...
# 359329  Фракция Политической партии "КОММУНИСТИЧЕСКАЯ ...
#
#                                                     lines
# 0       [фракция, единый, россия, спасибо, уважаемый, ...
# 1       [спасибо, уважаемый, борис, вячеславович, уваж...
# 2       [уважаемый, председательствующий, уважаемый, к...
# 3       [фракция, единый, россия, уважаемый, председат...
# 4       [фракция, единый, россия, уважаемый, председат...
# ...                                                   ...
# 359325                                              [нет]
# 359326  [фракция, коммунистический, партия, российский...
# 359327  [куваев, аа, фракция, коммунистический, партия...
# 359328  [куваев, аа, фракция, коммунистический, партия...
# 359329  [куваев, аа, избирательный, объединение, комму...
#
# [359330 rows x 14 columns]

# %%
# Сохранение датафрейма
with open('duma/data_dataframe_prep.pickle', 'wb') as dep:
    pickle.dump(data, dep)
